# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))


from src.infrastructure.mongo.service import MongoService
import pandas as pd

# %%
threads_collection = MongoService(collection_name="threads")
# Out:
# 2026-02-15 17:47:25.019 | INFO     | src.infrastructure.mongo.service:__init__:23 - Successfully connected to MongoDB collection: 'threads'

# %%
threads =threads_collection.find_many()
# Out:
# 2026-02-15 17:52:49.797 | INFO     | src.infrastructure.mongo.service:find_many:59 - Retrieved 38562 documents from threads

# %%
len([item for item in threads if item['message_count']>4])
# Out:
# 7412

# %%
df = pd.DataFrame([item for item in threads if item['message_count']>10])
df = df[['chat_name','thread_id','message_count','transcript']]
df.to_csv('threads.csv',index=False)

# %%
threads[0]
# Out:
# {'thread_id': '412335439_11',
#  'chat_id': 412335439,
#  'chat_name': 'LE CERCLE DES ECONOMISTES AFRICAINS',
#  'week_id': '2020-17',
#  'root_message_id': 11,
#  'transcript': "### CONVERSATION THREAD: LE CERCLE DES ECONOMISTES AFRICAINS\n### METADATA: 2 msgs | 543 mins duration\n### TRANSCRIPT: \n[2020-04-25 11:23] Elisee Yonta: Bonjour Luc et Eugene et bienvenu dans cette plateforme. SVP presentez vous aux autres membres. Cordialement\n[2020-04-25 20:26] Eugenio Ngondji: Salut tout le monde! Je suis Eugène, data engineer et économiste. Simple passionné de l'histoire et du devenir de la terre de mes ancêtres. Veuillez excuser la qualité de mon français dans les échanges à venir.",
# ...
